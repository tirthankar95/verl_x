# %%
from langchain_openai import ChatOpenAI
from langgraph.graph import (
    StateGraph,
    START,
    END
)
from typing_extensions import TypedDict
from IPython.display import Image, display
from pydantic import BaseModel, Field
from typing import List 
import random
import json 
from template2x2 import (
    get_temp0,
    get_temp1
)

# %%
class State(TypedDict):
    initial_prompt: str
    category: str 
    story: str
    clue: str 
    solution: str 
    final_prompt: str 

llm = ChatOpenAI(
    api_key="",
    model="gpt-4o"
)

# %%
def extract_json(msg: str):
    start_indx, end_indx = None, None 
    for idx, ch in enumerate(msg):
        if ch == '{':
            start_indx = idx 
            break
    for idx, ch in enumerate(msg):
        if ch == '}':
            end_indx = idx 
    if start_indx == None or end_indx == None:
        return "{}"
    return msg[start_indx: end_indx+1]

# %%
def category_prompt(state: State):
    x, y = state['initial_prompt']['row'], state['initial_prompt']['column']
    msg = llm.invoke(f"""
    You are an AI assistant who is an expert at designing grid logic puzzles. 
    
    I want to create a logic grid puzzle of size {x}*{y}. 
    This means the puzzle should have {x} categories, and each category should contain {y} distinct values.
    One of the category could be a numerical category like money, price, depth or date time. 
    Make the first category in the list of categories as numerical. 
    Rules:
    1. Dont pick weird values for categories. For example orange fruit and orange color, in such cases clues for grid puzzles will become ambiguous.
    2. Some examples of category triplets.
    (Depth of pool, Diver Name, Competition Year),
    (Dog graduation year, Police officer, Dog name),
    (Price, Person, Pet),
    (Price, Person, Fruits),
    ('Distance', 'Exo-Planet', 'Star')
    etc.
    
    Your task:
    1. Generate {x} category names that are intuitive and distinct.
    2. For each category, provide {y} values that are realistic, non-overlapping, and suitable for a logic grid puzzle.
    3. Return the result strictly in **valid JSON** format, with the structure:
    
    {{
        "categories": ["c1", "c2", ..., "c{x}"],
        "c1": ["c1_1", "c1_2", ..., "c1_{y}"],
        "c2": ["c2_1", "c2_2", ..., "c2_{y}"],
        ...
    }}
    No extra commentary or explanation. Only output valid JSON.
    """)
    return {'category': extract_json(msg.content)}

# %%
class Story(BaseModel):
    story: str = Field(
        description = "The story surrounding the logic grid puzzle."
    )
    clue: List[str] = Field(
        description = "The clues to solve the grid puzzle, each entry in a list is an independent clue."
    )

def story_clue_prompt(state: State):
    '''(2, 2) grid puzzles''' 
    def beautify(grid):
        result = ""
        for row in grid:
            temp_row = row.copy()
            temp_row = ' | '.join(row) 
            result += temp_row + "\n"
        return result
        
    '''Build Solution'''
    elements, dim = state['initial_prompt']['row'], state['initial_prompt']['column']
    st = json.loads(state['category'])
    keys = st['categories']
    cat = []
    for key in keys:
        row = st[key].copy()
        random.shuffle(row)
        cat.append(row)
    solution = [['' for _ in range(elements)] for __ in range(dim)]
    for i in range(elements):
        for j in range(dim):
            solution[j][i] = cat[i][j]
    soi = list(range(dim))
    random.shuffle(soi)
    ''' X '''
    
    problem_templates = [
        get_temp0(),
        get_temp1()
    ]
    index = random.randint(0, len(problem_templates)-1)
    llm.with_structured_output(Story)
    if index == 0:
        fin_prompt = problem_templates[index].format(keys, \
                keys[0], st[keys[0]], \
                keys[1], st[keys[1]], \
                solution[soi[0]][0], solution[soi[0]][1]
            )
    elif index == 1:
        fin_prompt = problem_templates[index].format(keys, \
                keys[0], st[keys[0]], \
                keys[1], st[keys[1]], \
                solution[soi[0]][0], solution[soi[1]][1]
            )
    resp = llm.invoke(fin_prompt)
    resp = json.loads(extract_json(resp.content))
    print(f'INDEX[{index}]; prompt> {fin_prompt}]')
    return {
        "solution": beautify(solution), 
        "story": resp['story'],
        "clue": resp['clues']
    }

'''TEST CODE'''
state = {
    'initial_prompt': { 'row': 2, 'column': 2 },
    'category': json.dumps({
        "categories": ["Month", "Dog"],
        "Month": ["March", "April"],
        "Dog": ["Pluto", "Donald"]
    }, indent=4)
}
story_clue_prompt(state)
# Out:
# INDEX[1]; prompt> Form a grid puzzle using the following template.
# A logic grid puzzle should have a story and clues.
#
# For example a 3x4 grid puzzle should have 3 categories, and each category should contain 4 distinct values.
# The solution to a grid puzzle
#
# Categories:
# ['Month', 'Dog']
#
# Month: ['March', 'April']
# Dog: ['Pluto', 'Donald']
#
# Clues:
# March is not related to Donald.
#
# Donot provide extra clues, if there is one clue under the sub topic Clues, provide only one clue.
# Your job is to fill in the following values in the following JSON.
# {
#     "story": "",
#     "clues": "",
# }
# No extra commentary or explanation. Only output valid JSON.]
# {'solution': 'March | Pluto\nApril | Donald\n',
#  'story': 'Four friends each adopted a dog in a different month. Based on the clues, determine which friend adopted which dog and in which month.',
#  'clue': 'March is not related to Donald.'}

# %%
# This doesn't go into the LLM.
def final_prompt(state: State):
    st = json.loads(state['category'])
    keys = st['categories']
    clues = state['clue']
    if isinstance(clues, list):
        clues = '\n'.join(clues)
    post_fix = f'''{state['story']}
Categories:
{keys}

{keys[0]}: {st[keys[0]]}
{keys[1]}: {st[keys[1]]}

Clues:
{clues}


While answering use the following format:
Step-by-step solution:
Your steps showing how you are solving the puzzle
Final Answer:
Create a table like this
c1_1 | c2_1 | c3_1
c1_2 | c2_2 | c3_2
c1_3 | c2_3 | c3_3
c1_4 | c2_4 | c3_4'''
    return {
        "final_prompt": post_fix
        }

# %%
workflow = StateGraph(State)
workflow.add_node('c_prompt', category_prompt)
workflow.add_node('sc_prompt', story_clue_prompt)
workflow.add_node('f_prompt', final_prompt)

workflow.add_edge(START, 'c_prompt')
workflow.add_edge('c_prompt', 'sc_prompt')
workflow.add_edge('sc_prompt', 'f_prompt')
workflow.add_edge('f_prompt', END)

chain = workflow.compile()

# %%
'''
row: how many elements are there 
column: how many values each category can have
'''
import pandas as pd 
EPOCHS = 10
for epoch in range(EPOCHS):
    state = chain.invoke({"initial_prompt":{
            "row": 2,
            "column": 2
            }
    })
    print(state['final_prompt'], state['solution'], \
        sep="\n-------------\n")
    df = pd.read_csv('data/grid_puzzle_easy_x.csv')
    old_shape = df.shape[0]
    new_row = pd.DataFrame({'question': [state['final_prompt']], 'answer': [state['solution']]})
    df = pd.concat([df, new_row], ignore_index=True)
    df.to_csv('data/grid_puzzle_easy_x.csv', index=False)
    new_shape = df.shape[0]
    assert new_shape > old_shape
# Out:
# INDEX[0]; prompt> Form a grid puzzle using the following template.
# A logic grid puzzle should have a story and clues.
#
# For example a 3x4 grid puzzle should have 3 categories, and each category should contain 4 distinct values.
# The solution to a grid puzzle
#
# Categories:
# ['Height in meters', 'Building Name']
#
# Height in meters: ['100', '200']
# Building Name: ['Skyscraper One', 'Tower Two']
#
# Clues:
# 200 and Tower Two are directly related.
#
# Donot provide extra clues, if there is one clue under the sub topic Clues, provide only one clue.
# Your job is to fill in the following values in the following JSON.
# {
#     "story": "",
#     "clues": "",
# }
# No extra commentary or explanation. Only output valid JSON.]
# In a small city, there are two newly constructed buildings that have become the talk of the town. Each building has a distinct height, and the challenge is to match the buildings with their respective heights.
# Categories:
# ['Height in meters', 'Building Name']
#
# Height in meters: ['100', '200']
# Building Name: ['Skyscraper One', 'Tower Two']
#
# Clues:
# 200 and Tower Two are directly related.
#
#
# While answering use the following format:
# Step-by-step solution:
# Your steps showing how you are solving the puzzle
# Final Answer:
# Create a table like this
# c1_1 | c2_1 | c3_1
# c1_2 | c2_2 | c3_2
# c1_3 | c2_3 | c3_3
# c1_4 | c2_4 | c3_4
# -------------
# 200 | Tower Two
# 100 | Skyscraper One
#
# INDEX[0]; prompt> Form a grid puzzle using the following template.
# A logic grid puzzle should have a story and clues.
#
# For example a 3x4 grid puzzle should have 3 categories, and each category should contain 4 distinct values.
# The solution to a grid puzzle
#
# Categories:
# ['Year of Discovery', 'Planet']
#
# Year of Discovery: ['2019', '2020']
# Planet: ['Mars', 'Venus']
#
# Clues:
# 2020 and Mars are directly related.
#
# Donot provide extra clues, if there is one clue under the sub topic Clues, provide only one clue.
# Your job is to fill in the following values in the following JSON.
# {
#     "story": "",
#     "clues": "",
# }
# No extra commentary or explanation. Only output valid JSON.]
# In a distant future, humans have made groundbreaking discoveries related to planets in our solar system. Two significant discoveries were made concerning Mars and Venus. Each discovery year is directly associated with one of these planets. Can you determine which planet was discovered in which year?
# Categories:
# ['Year of Discovery', 'Planet']
#
# Year of Discovery: ['2019', '2020']
# Planet: ['Mars', 'Venus']
#
# Clues:
# 2020 and Mars are directly related.
#
#
# While answering use the following format:
# Step-by-step solution:
# Your steps showing how you are solving the puzzle
# Final Answer:
# Create a table like this
# c1_1 | c2_1 | c3_1
# c1_2 | c2_2 | c3_2
# c1_3 | c2_3 | c3_3
# c1_4 | c2_4 | c3_4
# -------------
# 2020 | Mars
# 2019 | Venus
#
# INDEX[1]; prompt> Form a grid puzzle using the following template.
# A logic grid puzzle should have a story and clues.
#
# For example a 3x4 grid puzzle should have 3 categories, and each category should contain 4 distinct values.
# The solution to a grid puzzle
#
# Categories:
# ['Temperature (°C)', 'City']
#
# Temperature (°C): ['10°C', '25°C']
# City: ['New York', 'Los Angeles']
#
# Clues:
# 10°C is not related to Los Angeles.
#
# Donot provide extra clues, if there is one clue under the sub topic Clues, provide only one clue.
# Your job is to fill in the following values in the following JSON.
# {
#     "story": "",
#     "clues": "",
# }
# No extra commentary or explanation. Only output valid JSON.]
# Four friends recently traveled to two different cities on the same day. They experienced different temperatures in each city. Can you figure out the temperature in each city?
# Categories:
# ['Temperature (°C)', 'City']
#
# Temperature (°C): ['10°C', '25°C']
# City: ['New York', 'Los Angeles']
#
# Clues:
# 10°C is not related to Los Angeles.
#
#
# While answering use the following format:
# Step-by-step solution:
# Your steps showing how you are solving the puzzle
# Final Answer:
# Create a table like this
# c1_1 | c2_1 | c3_1
# c1_2 | c2_2 | c3_2
# c1_3 | c2_3 | c3_3
# c1_4 | c2_4 | c3_4
# -------------
# 10°C | Los Angeles
# 25°C | New York
#
# INDEX[1]; prompt> Form a grid puzzle using the following template.
# A logic grid puzzle should have a story and clues.
#
# For example a 3x4 grid puzzle should have 3 categories, and each category should contain 4 distinct values.
# The solution to a grid puzzle
#
# Categories:
# ['Ticket Price', 'Movie Genre']
#
# Ticket Price: ['$10', '$15']
# Movie Genre: ['Action', 'Comedy']
#
# Clues:
# $15 is not related to Action.
#
# Donot provide extra clues, if there is one clue under the sub topic Clues, provide only one clue.
# Your job is to fill in the following values in the following JSON.
# {
#     "story": "",
#     "clues": "",
# }
# No extra commentary or explanation. Only output valid JSON.]
# Four friends went to the movie theater, each buying a different genre ticket at different prices. Can you determine which ticket price matches each movie genre?
# Categories:
# ['Ticket Price', 'Movie Genre']
#
# Ticket Price: ['$10', '$15']
# Movie Genre: ['Action', 'Comedy']
#
# Clues:
# $15 is not related to Action.
#
#
# While answering use the following format:
# Step-by-step solution:
# Your steps showing how you are solving the puzzle
# Final Answer:
# Create a table like this
# c1_1 | c2_1 | c3_1
# c1_2 | c2_2 | c3_2
# c1_3 | c2_3 | c3_3
# c1_4 | c2_4 | c3_4
# -------------
# $15 | Action
# $10 | Comedy
#
# INDEX[0]; prompt> Form a grid puzzle using the following template.
# A logic grid puzzle should have a story and clues.
#
# For example a 3x4 grid puzzle should have 3 categories, and each category should contain 4 distinct values.
# The solution to a grid puzzle
#
# Categories:
# ['Price', 'Fruit']
#
# Price: ['$1', '$2']
# Fruit: ['Apple', 'Banana']
#
# Clues:
# $2 and Apple are directly related.
#
# Donot provide extra clues, if there is one clue under the sub topic Clues, provide only one clue.
# Your job is to fill in the following values in the following JSON.
# {
#     "story": "",
#     "clues": "",
# }
# No extra commentary or explanation. Only output valid JSON.]
# At the farmer's market, different fruits were being sold at different prices. There are four stalls, each selling a different fruit at a different price. Your task is to determine which fruit is sold at which price.
# Categories:
# ['Price', 'Fruit']
#
# Price: ['$1', '$2']
# Fruit: ['Apple', 'Banana']
#
# Clues:
# $2 and Apple are directly related.
#
#
# While answering use the following format:
# Step-by-step solution:
# Your steps showing how you are solving the puzzle
# Final Answer:
# Create a table like this
# c1_1 | c2_1 | c3_1
# c1_2 | c2_2 | c3_2
# c1_3 | c2_3 | c3_3
# c1_4 | c2_4 | c3_4
# -------------
# $1 | Banana
# $2 | Apple
#
# INDEX[0]; prompt> Form a grid puzzle using the following template.
# A logic grid puzzle should have a story and clues.
#
# For example a 3x4 grid puzzle should have 3 categories, and each category should contain 4 distinct values.
# The solution to a grid puzzle
#
# Categories:
# ['Weight', 'Animal']
#
# Weight: ['45 kg', '60 kg']
# Animal: ['Dog', 'Cat']
#
# Clues:
# 60 kg and Cat are directly related.
#
# Donot provide extra clues, if there is one clue under the sub topic Clues, provide only one clue.
# Your job is to fill in the following values in the following JSON.
# {
#     "story": "",
#     "clues": "",
# }
# No extra commentary or explanation. Only output valid JSON.]
# Four friends are having a contest to see who can finish a puzzle the quickest. Each person has their own type of puzzle with a different number of pieces. Determine which puzzle type and number of pieces each person has.
# Categories:
# ['Weight', 'Animal']
#
# Weight: ['45 kg', '60 kg']
# Animal: ['Dog', 'Cat']
#
# Clues:
# Emma has the crossword puzzle.
#
#
# While answering use the following format:
# Step-by-step solution:
# Your steps showing how you are solving the puzzle
# Final Answer:
# Create a table like this
# c1_1 | c2_1 | c3_1
# c1_2 | c2_2 | c3_2
# c1_3 | c2_3 | c3_3
# c1_4 | c2_4 | c3_4
# -------------
# 60 kg | Cat
# 45 kg | Dog
#
# INDEX[0]; prompt> Form a grid puzzle using the following template.
# A logic grid puzzle should have a story and clues.
#
# For example a 3x4 grid puzzle should have 3 categories, and each category should contain 4 distinct values.
# The solution to a grid puzzle
#
# Categories:
# ['Price', 'Pet']
#
# Price: ['$50', '$100']
# Pet: ['Dog', 'Cat']
#
# Clues:
# $50 and Dog are directly related.
#
# Donot provide extra clues, if there is one clue under the sub topic Clues, provide only one clue.
# Your job is to fill in the following values in the following JSON.
# {
#     "story": "",
#     "clues": "",
# }
# No extra commentary or explanation. Only output valid JSON.]
# Three friends, Alice, Bob, and Carol, recently bought different expensive pets, one for each, from the same pet shop. The pets cost different amounts, and each pet was a different type. Determine which pet each person got and how much they paid for it.
# Categories:
# ['Price', 'Pet']
#
# Price: ['$50', '$100']
# Pet: ['Dog', 'Cat']
#
# Clues:
# Carol's pet cost $300.
#
#
# While answering use the following format:
# Step-by-step solution:
# Your steps showing how you are solving the puzzle
# Final Answer:
# Create a table like this
# c1_1 | c2_1 | c3_1
# c1_2 | c2_2 | c3_2
# c1_3 | c2_3 | c3_3
# c1_4 | c2_4 | c3_4
# -------------
# $100 | Cat
# $50 | Dog
#
# INDEX[1]; prompt> Form a grid puzzle using the following template.
# A logic grid puzzle should have a story and clues.
#
# For example a 3x4 grid puzzle should have 3 categories, and each category should contain 4 distinct values.
# The solution to a grid puzzle
#
# Categories:
# ['Price', 'Pet']
#
# Price: ['$10', '$20']
# Pet: ['Cat', 'Dog']
#
# Clues:
# $20 is not related to Cat.
#
# Donot provide extra clues, if there is one clue under the sub topic Clues, provide only one clue.
# Your job is to fill in the following values in the following JSON.
# {
#     "story": "",
#     "clues": "",
# }
# No extra commentary or explanation. Only output valid JSON.]
# Four friends recently bought new pets at different prices. Each friend got either a Cat or a Dog, and they spent either $10 or $20 on their pet. Try to figure out which pet each person bought and at what price.
# Categories:
# ['Price', 'Pet']
#
# Price: ['$10', '$20']
# Pet: ['Cat', 'Dog']
#
# Clues:
# $20 is not related to Cat.
#
#
# While answering use the following format:
# Step-by-step solution:
# Your steps showing how you are solving the puzzle
# Final Answer:
# Create a table like this
# c1_1 | c2_1 | c3_1
# c1_2 | c2_2 | c3_2
# c1_3 | c2_3 | c3_3
# c1_4 | c2_4 | c3_4
# -------------
# $10 | Dog
# $20 | Cat
#
# INDEX[0]; prompt> Form a grid puzzle using the following template.
# A logic grid puzzle should have a story and clues.
#
# For example a 3x4 grid puzzle should have 3 categories, and each category should contain 4 distinct values.
# The solution to a grid puzzle
#
# Categories:
# ['Price', 'Fruit']
#
# Price: ['$3', '$5']
# Fruit: ['Apple', 'Banana']
#
# Clues:
# $5 and Apple are directly related.
#
# Donot provide extra clues, if there is one clue under the sub topic Clues, provide only one clue.
# Your job is to fill in the following values in the following JSON.
# {
#     "story": "",
#     "clues": "",
# }
# No extra commentary or explanation. Only output valid JSON.]
# At the farmer's market, there are four vendors each selling a unique combination of fruit at a certain price. Can you figure out who is selling what and at what price based on the given clues?
# Categories:
# ['Price', 'Fruit']
#
# Price: ['$3', '$5']
# Fruit: ['Apple', 'Banana']
#
# Clues:
# Vendor C is selling a fruit priced at $7.
#
#
# While answering use the following format:
# Step-by-step solution:
# Your steps showing how you are solving the puzzle
# Final Answer:
# Create a table like this
# c1_1 | c2_1 | c3_1
# c1_2 | c2_2 | c3_2
# c1_3 | c2_3 | c3_3
# c1_4 | c2_4 | c3_4
# -------------
# $3 | Banana
# $5 | Apple
#
# INDEX[0]; prompt> Form a grid puzzle using the following template.
# A logic grid puzzle should have a story and clues.
#
# For example a 3x4 grid puzzle should have 3 categories, and each category should contain 4 distinct values.
# The solution to a grid puzzle
#
# Categories:
# ['Weight (kg)', 'Animal']
#
# Weight (kg): ['150 kg', '200 kg']
# Animal: ['Lion', 'Tiger']
#
# Clues:
# 150 kg and Lion are directly related.
#
# Donot provide extra clues, if there is one clue under the sub topic Clues, provide only one clue.
# Your job is to fill in the following values in the following JSON.
# {
#     "story": "",
#     "clues": "",
# }
# No extra commentary or explanation. Only output valid JSON.]
# At a wildlife sanctuary, different animals are undergoing a health evaluation. Among the animals, there is a lion and a tiger, each with a specific weight. Due to a mix-up in the records, their weights need to be accurately matched with the respective animals. The objective is to determine which animal matches with each given weight.
# Categories:
# ['Weight (kg)', 'Animal']
#
# Weight (kg): ['150 kg', '200 kg']
# Animal: ['Lion', 'Tiger']
#
# Clues:
# 150 kg and Lion are directly related.
#
#
# While answering use the following format:
# Step-by-step solution:
# Your steps showing how you are solving the puzzle
# Final Answer:
# Create a table like this
# c1_1 | c2_1 | c3_1
# c1_2 | c2_2 | c3_2
# c1_3 | c2_3 | c3_3
# c1_4 | c2_4 | c3_4
# -------------
# 150 kg | Lion
# 200 kg | Tiger
